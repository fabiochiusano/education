# %%
import numpy as np
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import json
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from bs4.element import Tag

# %%
def remove_hidden(l):
    return [el for el in l if el[0] != "."]

def get_relative_path_to_dirs(start_path):
    subdirs = [x[1] for x in os.walk(start_path)][0]
    subdirs = remove_hidden(subdirs)
    subdirs = [start_path + "/" + subdir for subdir in subdirs]
    return subdirs

def get_relative_path_to_files(start_path):
    files = [f for f in listdir(start_path) if isfile(join(start_path, f))]
    files = remove_hidden(files)
    files = [start_path + "/" + file for file in files]
    return files

# %%
home_articles_directory = "../articles"

subdirs = get_relative_path_to_dirs(home_articles_directory)
subdirs
# Out:
# ['../articles/medium',
#  '../articles/tutorialspoint',
#  '../articles/wikihow',
#  '../articles/kdnuggets',
#  '../articles/smartdatacollective']

# %%
data = {}

for subdir in subdirs:
    subsubdirs = get_relative_path_to_dirs(subdir)
    sub_data = {}
    for subsubdir in subsubdirs:
        onlyfiles = get_relative_path_to_files(subsubdir)
        read_json_list = []
        for file in onlyfiles:
            with open(file, 'r') as infile:
                d = json.load(infile)
                read_json_list.append(d)
        sub_data[subsubdir] = read_json_list
    data[subdir] = sub_data

# %% [markdown]
# ## Number of scraped tutorials per website

# %%
data_plt = {}
for k,v in data.items():
    for k2,v2 in v.items():
        data_plt[k2.split("/")[-1]] = len(v2)

fig = plt.figure(figsize=(20,10))
plt.bar(range(len(data_plt)), list(data_plt.values()), align='center')
plt.xticks(range(len(data_plt)), list(data_plt.keys()), rotation=90)

plt.show()

# %% [markdown]
# ## Average lenght of title html per website

# %%
data_plt = {}
for k,v in data.items():
    for k2,v2 in v.items():
        data_plt[k2.split("/")[-1]] = sum([len(j["html"]) for j in v2]) / len(v2)

fig = plt.figure(figsize=(20,10))
plt.bar(range(len(data_plt)), list(data_plt.values()), align='center')
plt.xticks(range(len(data_plt)), list(data_plt.keys()), rotation=90)

plt.show()

# %% [markdown]
# ## Average title length per website

# %%
data_plt = {}
for k,v in data.items():
    for k2,v2 in v.items():
        data_plt[k2.split("/")[-1]] = sum([len(j["title"]) for j in v2]) / len(v2)

fig = plt.figure(figsize=(20,10))
plt.bar(range(len(data_plt)), list(data_plt.values()), align='center')
plt.xticks(range(len(data_plt)), list(data_plt.keys()), rotation=90)

plt.show()

# %%
data_plt = {}
for k,v in data.items():
    for k2,v2 in v.items():
        data_plt[k2.split("/")[-1]] = sum([len(j["title"].split(" ")) for j in v2]) / len(v2)

fig = plt.figure(figsize=(20,10))
plt.bar(range(len(data_plt)), list(data_plt.values()), align='center')
plt.xticks(range(len(data_plt)), list(data_plt.keys()), rotation=90)

plt.show()

# %% [markdown]
# ## Sample titles

# %%
import random

# %%
for k1,v1 in data.items():
    for k2,v2 in v1.items():
        random_selected = np.random.choice(v2, size=5, replace=True)
        titles_and_urls = [(el["title"], el["url"]) for el in random_selected]
        print(k2 + ":")
        for t,u in titles_and_urls:
            print(t + " --> " + u)
        print("---------")
# Out:
# ../articles/kdnuggets/www.kdnuggets.com:
# R, Python Duel As Top Analytics, Data Science software – KDnuggets 2016 Software Poll Results --> https://www.kdnuggets.com/2016/06/r-python-top-analytics-data-mining-data-science-software.html
# How to Choose the Right Chart Type --> https://www.kdnuggets.com/2019/03/how-choose-right-chart-type.html
# Texas A&M Institute of Data Science: Staff Data Scientist [College Station, TX] --> https://www.kdnuggets.com/jobs/19/03-21-texas-am-institute-data-science-data-scientist.html
# XAI – A Data Scientist’s Mouthpiece --> https://www.kdnuggets.com/2019/04/xai-data-scientist.html
# Gain the Skills You Need to Level-Up in Your Data-Driven Career --> https://www.kdnuggets.com/2019/03/delaware-gain-skills-need-data-driven-career.html
# ---------
# ../articles/tutorialspoint/store.tutorialspoint.com:
# E-Book Store
#
#   Categories
#
#  --> https://store.tutorialspoint.com
# E-Book Store
#
#   Categories
#
#  --> https://store.tutorialspoint.com
# E-Book Store
#
#   Categories
#
#  --> https://store.tutorialspoint.com
# E-Book Store
#
#   Categories
#
#  --> https://store.tutorialspoint.com
# E-Book Store
#
#   Categories
#
#  --> https://store.tutorialspoint.com
# ---------
# ../articles/tutorialspoint/www.tutorialspoint.com:
# Indian Economy Tutorial --> https://www.tutorialspoint.com/indian_economy/index.htm
# Reasoning Tutorial --> https://www.tutorialspoint.com/reasoning/index.htm
# DCN - Useful Resources --> https://www.tutorialspoint.com/data_communication_computer_network/dcn_useful_resources.htm
# C++ Signal Handling --> https://www.tutorialspoint.com/cplusplus/cpp_signal_handling.htm
# Current Affairs March 2016 --> https://www.tutorialspoint.com/current_affairs_march_2016/index.htm
# ---------
# ../articles/wikihow/www.wikihow.com:
# How to Build a Spaghetti Tower --> https://www.wikihow.com/Build-a-Spaghetti-Tower
# How to Make a Butterfly from a Plastic Straw and Scratch Paper --> https://www.wikihow.com/Make-a-Butterfly-from-a-Plastic-Straw-and-Scratch-Paper
# How to Make a Butterfly from a Plastic Straw and Scratch Paper --> https://www.wikihow.com/Make-a-Butterfly-from-a-Plastic-Straw-and-Scratch-Paper
# How to Build a Spaghetti Tower --> https://www.wikihow.com/Build-a-Spaghetti-Tower
# How to Set a Breakfast Table --> https://www.wikihow.com/Set-a-Breakfast-Table
# ---------
# ../articles/smartdatacollective/www.smartdatacollective.com:
# AI Streamlines Content Curation Strategies In Digital Marketing --> https://www.smartdatacollective.com/ai-streamlines-content-curation-strategies-in-digital-marketing
# Your Guide To Understanding Various Types of Data Masking --> https://www.smartdatacollective.com/guide-to-understanding-various-types-of-data-masking
# User Adoption – Resistance Is Futile, We Hope --> https://www.smartdatacollective.com/user-adoption-resistance-it-futile-we-hope
# ---------
# ../articles/medium/medium.freecodecamp.org:
# How to center things with style in CSS --> https://medium.freecodecamp.org/how-to-center-things-with-style-in-css-dc87b7542689
# Helping blind people learn to code --> https://medium.freecodecamp.org/helping-blind-people-learn-to-code-c47c68d4a237
# Introducing Programmer Playing Cards --> https://medium.freecodecamp.org/introducing-programmer-playing-cards-d3eeeffe9a11
# How I went from newbie to Software Engineer in 9 months while working full time --> https://medium.freecodecamp.org/how-i-went-from-newbie-to-software-engineer-in-9-months-while-working-full-time-460bd8485847
# How I went from newbie to Software Engineer in 9 months while working full time --> https://medium.freecodecamp.org/how-i-went-from-newbie-to-software-engineer-in-9-months-while-working-full-time-460bd8485847
# ---------
# ../articles/medium/medium.com:
# Lessons from the Blue Zones on How to Live Longer --> https://medium.com/infinite-mindspace/eternal-life-biohacking-and-longevity-secrets-of-the-blue-zone-9c38d0ed009c
# FaceTime ≠ Face-to-face Time --> https://medium.com/handsome-perspectives/facetime-isnt-face-to-face-time-f5766585f262
# We’re All in Show Business --> https://medium.com/handsome-perspectives/were-all-in-show-business-93603694dd3f
# The Science Behind Poor Sleep and How to Fix It --> https://medium.com/infinite-mindspace/this-is-why-you-are-not-sleeping-well-e2b1f14b8d61
# Tarot Cards: A Tool of Cold Tricksters or Wise Therapists? --> https://medium.com/aeon-magazine/tarot-cards-a-tool-of-cold-tricksters-or-wise-therapists-1da6efb5179d
# ---------

# %% [markdown]
# ## Sample article HTML tag chains

# %%
for k1,v1 in data.items():
    for k2,v2 in v1.items():
        random_selected = np.random.choice(v2, size=5, replace=True)
        chtml_and_urls = [(el["content_html"], el["url"]) for el in random_selected]
        print(k2 + ":")
        for chtml,u in chtml_and_urls:
            soup = BeautifulSoup(chtml)
            chain = list(list(soup.select("body")[0].descendants)[0].descendants)
            chain_list = []
            for el in chain:
                if type(el) == Tag:
                    chain_list.append(el.name)
            print(" ".join(chain_list) + " ---> " + u)
        print("---------")
# Out:
# ../articles/tutorialspoint/store.tutorialspoint.com:
# h1 div a i i div ul li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i div div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i ---> https://store.tutorialspoint.com
# h1 div a i i div ul li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i div div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i ---> https://store.tutorialspoint.com
# h1 div a i i div ul li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i div div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i ---> https://store.tutorialspoint.com
# h1 div a i i div ul li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i div div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i ---> https://store.tutorialspoint.com
# h1 div a i i div ul li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i li a i div div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i div div a span img div div div br a b a b i ---> https://store.tutorialspoint.com
# ---------
# ../articles/tutorialspoint/www.tutorialspoint.com:
# div div img ul li li a li a li a li a li a li a ul li li a li a li a li a ul li li a li a li a li a li a li a li a div div img hr h1 div div script script hr ul li p i strong li p i strong a hr form div div label input div label i input div label input div label i textarea div div div br input div script div div a i div a i div div script script div div div div script script div script script div script script div ---> https://www.tutorialspoint.com/about/contact_us.htm
# h1 hr div div script script hr div a i div a i div hr p ul li p b li p b p p b p b h2 p b pre p b b pre p pre p b p pre p a i pre p pre h2 p pre p pre p pre p pre h2 p a i pre p p pre hr div a i div a i div a i hr div div script script ---> https://www.tutorialspoint.com/cplusplus/cpp_dynamic_memory.htm
# h1 hr div div script script hr div a i div a i div hr p p ul li li h2 p b p b b p pre p pre h2 p p b b i a pre p pre h2 p pre p b i b i pre p pre h3 p pre h3 pre p pre h3 pre p b p pre h3 p i pre p pre hr div a i div a i div a i hr div div script script ---> https://www.tutorialspoint.com/plsql/plsql_packages.htm
# div div img ul li li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li a li li a li a li a ul li li a li a li a li a li a li a li a div div img hr h1 div div form input button i a button i a button i a button i button i a p h1 p p h1 p div div a i div a i div div script script div div div div script script div script script div script script div ---> https://www.tutorialspoint.com/computer_fundamentals/index.htm
# h1 div small div hr script script hr div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div div div a img h2 a div em a div div div script ins script div div div a div div div script script ---> https://www.tutorialspoint.com/articles/index.php
# ---------
# ../articles/medium/medium.freecodecamp.com:
# h1 div div a div img div svg path path div div a span button span span button span span div time span span ---> https://medium.freecodecamp.com/mark-zuckerberg-is-the-most-powerful-person-on-earth-but-is-he-responsible-5fbcaeb29ee1
# h1 div div a div img div svg path path div div a span button span span button span span div time span span ---> https://medium.freecodecamp.com/all-of-2016s-top-mobile-apps-are-owned-by-either-google-or-facebook-a9c56d77a74b
# h1 div div a div img div svg path path div div a span button span span button span span div time span span ---> https://medium.freecodecamp.com/inside-the-invisible-war-for-the-open-internet-dd31a29a3f08
# h1 div div a div img div svg path path div div a span button span span button span span div time span span ---> https://medium.freecodecamp.com/all-of-2016s-top-mobile-apps-are-owned-by-either-google-or-facebook-a9c56d77a74b
# h1 div div a div img div svg path path div div a span button span span button span span div time span span ---> https://medium.freecodecamp.com/mark-zuckerberg-is-the-most-powerful-person-on-earth-but-is-he-responsible-5fbcaeb29ee1
# ---------
# ../articles/medium/humanparts.medium.com:
# h1 h2 div div a div img div svg path path div div a span button span span button span span div time span span span span svg path ---> https://humanparts.medium.com/i-know-i-should-post-other-memes-but-i-cant-move-on-from-evil-kermit-b8a50c5fb540
# h1 em h2 em div div a div img div svg path path div div a span button span span button span span div time span span span span svg path figure div div div img canvas img noscript img figcaption p span span span img span p p p p blockquote p p p ---> https://humanparts.medium.com/metoo-and-the-myth-of-millennial-fragility-d2f5257a4304
# h1 h2 div div a div img div svg path path div div a span button span span button span span div time span span span span svg path ---> https://humanparts.medium.com/i-am-a-little-too-fat-im-a-little-too-generous-i-think-i-know-why-e97cd25b7eeb
# h1 strong h2 div div a div img div svg path path div div a span button span span button span span div time span span span span svg path figure div div div img canvas img noscript img figcaption p span span span img span p em p blockquote p p em p ---> https://humanparts.medium.com/dating-in-the-multiverse-3ad0e1a0e8a3
# h1 h2 div div a div img div svg path path div div a span button span span button span span div time span span span span svg path figure div div div img canvas img noscript img figcaption p p p p p p p a p p a a p a p blockquote p em blockquote p figure div div div img canvas img noscript img figcaption p ---> https://humanparts.medium.com/divine-feminine-wisdom-for-a-world-gone-mad-16301632c4f8
# ---------
# ../articles/medium/onezero.medium.com:
# h1 strong h2 em div div a img div div a span button span span button span span div time span span span span svg path figure div div div img canvas img noscript img p p a p p a a p p p p em p blockquote p p p p p p ---> https://onezero.medium.com/i-cant-live-without-calm-c660b6525ff1
# h1 h2 em div div a div img div svg path path div div a span button span span button span span div time span span span span svg path ---> https://onezero.medium.com/the-end-of-apples-screen-time-ed13a050c5dd
# h1 h2 div div a img div div a span button span span button span span div time span span span span svg path ---> https://onezero.medium.com/the-engineer-using-a-i-to-read-your-feelings-bc2843437f02
# h1 h2 div div a img div div a span button span span button span span div time span span span span svg path ---> https://onezero.medium.com/the-gig-economy-makes-workers-vulnerable-to-sexual-harassment-53208dfb5b5a
# h1 strong h2 em div div a div img div svg path path div div a span button span span button span span div time span span span span svg path ---> https://onezero.medium.com/meet-the-woman-pushing-for-more-gender-diversity-on-wikipedia-3aea131484f6
# ---------
# ../articles/medium/blog.medium.com:
# h1 h2 div div a div img div svg path path div div a span button span span button span span div time span
div div a div img div svg path path div div a span button span span button span span div time span span span span svg path figure div div div img canvas img noscript img p strong p p p p p em a em em p strong figure div div div img canvas div iframe noscript div iframe figcaption h3 p p strong ol li li li p p p strong h3 p p strong p p p p h3 p p strong p p p ol li li li p p p p figure div div div img canvas div iframe noscript div iframe figcaption h3 p p p p p strong p strong p p p p strong h3 figure div div div img canvas div iframe noscript div iframe figcaption p p strong a strong p ol li li li li p p p p strong strong p p strong p strong em em a em em p em a em em ---> https://medium.freecodecamp.org/how-to-center-things-with-style-in-css-dc87b7542689
# ---------
# ../articles/medium/medium.com:
# figure div div a img h1 div div a img div div a span button span span button span span div time span span span span svg path p p p p div a strong br em a p p figure div div div img canvas img noscript img p p p p p strong figure div div div img canvas img noscript img p p strong ul li li p strong ul li li li p strong figure div div div img canvas img noscript img p p p strong ul li li p strong ul li li p strong figure div div div img canvas img noscript img p p strong ul li p strong ul li p p blockquote p figure div div div img canvas div iframe noscript div iframe ---> https://medium.com/datadriveninvestor/integrating-machine-learning-models-within-matured-business-process-7d6fec8337ff
# h1 div div a div img div svg path path div div a span button span span button span span div time span span span span svg path ---> https://medium.com/infinite-mindspace/eternal-life-biohacking-and-longevity-secrets-of-the-blue-zone-9c38d0ed009c
# h1 div div a img div div a span button span span button span span div time span span span span svg path figure div div div img canvas img noscript img figcaption p p p p a a h3 p p p p p figure div div div img canvas img noscript img p p a blockquote p p h3 p a p a p p p p a p a p h3 p p h4 p p p p h4 p p a p p p a h4 p p a p p a p p h4 p p p p a p p h4 p p p p p ---> https://medium.com/right-as-rain/debunking-hollywood-what-sci-fi-movies-get-wrong-about-memory-and-learning-e51b17324dd8
# h1 strong div div a img div div a span button span span button span span div time span span figure div div div img canvas img noscript img figcaption p p p strong p em em em em p p strong p p em p strong p p figure div div div img canvas img noscript img p strong p p p strong p p a p p a h3 p p strong p a p a p a figure div div img ---> https://medium.com/building-rigup/my-journey-to-rigup-209754312370
# h1 strong div div a img div div a span button span span button span span div time span span ---> https://medium.com/handsome-perspectives/taking-time-to-come-together-a-handsome-leadership-offsite-7ba6d8c90047
# ---------

# %% [markdown]
# ## Queue length

# %%
#queue_length = ...

#plt.plot(range(len(queue_length)), queue_length)

# %% [markdown]
# ## Assign a duration to each article

# %% [markdown]
# Duration depends on content length.

# %%
wps = 200 / 60 # = 3.33 

for k1,v1 in data.items():
    for k2,v2 in v1.items():
        for i,f in enumerate(v2):
            num_of_words = len(f["content"].split(" "))
            read_time = num_of_words / wps
            f["read_time"] = read_time

# %%
data_plt = {}
for k,v in data.items():
    for k2,v2 in v.items():
        data_plt[k2.split("/")[-1]] = sum([j["read_time"] for j in v2]) / len(v2)

fig = plt.figure(figsize=(20,10))
plt.bar(range(len(data_plt)), list(data_plt.values()), align='center')
plt.xticks(range(len(data_plt)), list(data_plt.keys()), rotation=90)

plt.show()

# %%
list(data["../articles/wikihow"].keys())
# Out:
# ['../articles/wikihow/www.wikihow.com']
